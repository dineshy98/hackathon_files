# %%
import pandas as pd
import matplotlib.pyplot as plt

festman_followers = pd.read_excel('S:/Hackathons/FestMan/festman_followers.xls')
festman_visitors = pd.read_excel('S:/Hackathons/FestMan/festman_visitors.xls')


festman_updates = pd.read_excel('S:/Hackathons/FestMan/festman_updates.xls')
festman_updates.columns = festman_updates.iloc[0]
festman_updates.drop([0],inplace = True)

festman_visitors = pd.read_excel('S:/Hackathons/FestMan/festman_visitors.xls')

# %% [markdown]
# ## 1.Multi- Series Plots

# %%
def multiseries_plts(df):

    df.plot(linewidth=0.5,figsize = (15,10))
    plt.show()

# %%
multiseries_plts(festman_followers)

# %%
multiseries_plts(festman_updates)

# %%
multiseries_plts(festman_followers)

# %% [markdown]
# ## 2.Sub Plots

# %%
def sub_plts(df,fig_x,fig_y,l_x,l_y):

    df.plot(subplots=True,linewidth=0.5,layout=(l_x,l_y),figsize=(fig_x, fig_y),sharex=False,sharey=True)
    plt.show()

# %%
multiline_plts(festman_followers,15,10,3,1)

# %%
festman_updates.shape
# Out:
# (365, 20)

# %%
sub_plts(festman_updates,15,30,5,4)

# %%
festman_visitors.shape
# Out:
# (365, 25)

# %%
sub_plts(festman_visitors,15,60,8,3)
